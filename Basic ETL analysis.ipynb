# %% [markdown]
# # 8a

# %%
import pandas as pd

# %%
#. This code load the data for college 
college = pd.read_csv("college.csv")

# to call the data will load xand named college 
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
# This code show the first 5 data in the college data
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# # 8b

# %%
#This code is to read the college data again and this time use the first colum as index and now name the dataframe college2
college2 = pd.read_csv("college.csv",
                       index_col= 0)

# %%
# here will create a new college3 which has the first column in the college data renamed from "Unnamed:0" to "College"
college3 = college.rename({"Unnamed: 0" : "College"}, 
                         axis = 1)

# %%
# After we change the "Unnamed: 0" to "College" we now set the College as index for the data
college3 = college3.set_index("College")

# %%
# this code shows the first 5 data of college2 with the first column set as index for the data
college2.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
# this code shows the first 5 data of college3 with column College set as index for the data
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
# this code is so set college as the new data frame "college3" which has 'College' column as index
college = college3

# %% [markdown]
# # 8c.

# %%
# This code is used to show the numerical summery of all the columns such as count,mean,max and the percentiles
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# # 8d.

# %%
# This code is to draw a scatter matrix for the column Top10perc,Apps and Enroll againt each other in matrix format
pd.plotting.scatter_matrix(college[["Top10perc","Apps","Enroll"]],
                           figsize =(12,12))
# Out:
# array([[<AxesSubplot:xlabel='Top10perc', ylabel='Top10perc'>,
#         <AxesSubplot:xlabel='Apps', ylabel='Top10perc'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Top10perc'>],
#        [<AxesSubplot:xlabel='Top10perc', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Apps', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Apps'>],
#        [<AxesSubplot:xlabel='Top10perc', ylabel='Enroll'>,
#         <AxesSubplot:xlabel='Apps', ylabel='Enroll'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# # 8e.

# %%
# This code plot a boxplot for the column Outstate and Private and the boxplot was grouped by the private column
college.boxplot("Outstate", "Private", 
                figsize = (10,10))
# Out:
# <AxesSubplot:title={'center':'Outstate'}, xlabel='Private'>

# %% [markdown]
# # 8f.

# %%
# This code creates a new column "Elite" and also fill it with yes and no depending on the value in the Top10perc column. 
#If the value is less than 49 the Elite column will be NO, but if the Top10perc is >= 50 and <= 100 the Elite column will be YES
college['Elite'] = pd.cut(college['Top10perc'],
                          [0, 50, 100],
                          labels=['No', 'Yes'])

# %%
# this code is to show the value counts of each values in the Elite column
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %% [markdown]
# The new column Elite has 699 value counts for No and 78 value counts for Yes

# %%
#  This code plot a boxplot of Outstate and Elite and the plot is grouped by Elite.
college.boxplot(column='Outstate', by='Elite',
                figsize =(10,10))
# Out:
# <AxesSubplot:title={'center':'Outstate'}, xlabel='Elite'>

# %% [markdown]
# # 8g.

# %%
# This code below is used to import the matplotlib.pyplot libraries needed for the subplots
from matplotlib.pyplot import subplots
import matplotlib.pyplot as plt

# This code below is to set the subplot for the histogram and also use the axes to plot histogram for Top10perc,Apps,
# Grad.rate, and Enroll.
fig , axes = plt.subplots(nrows =2, ncols=2, figsize =(14,10))
college["Top10perc"].plot.hist(ax=axes[0,0],
                              bins = 10)
axes[0,0].set_title("HISTOGRAM OF TOP10 PERC") # this code is used to create the title for each plot on the subplot 


college["Apps"].plot.hist(ax=axes[0,1],
                              bins = 20,
                         color = "green",
                         xlim = 0)
axes[0,1].set_title("HISTOGRAM OF APPS")


college["Grad.Rate"].plot.hist(ax=axes[1,0],
                              bins = 15,
                              color = "grey")
axes[1,0].set_title("HISTOGRAM OF GRAD.RATE")
                               
                               
college["Enroll"].plot.hist(ax=axes[1,1],
                              bins = 25,
                              color = "orange")
axes[1,1].set_title("HISTOGRAM OF ENROLL")
# Out:
# Text(0.5, 1.0, 'HISTOGRAM OF ENROLL')

# %% [markdown]
# # 10a

# %%
# Loading of the Boston dataset using pandas
boston = pd.read_csv("Boston.csv")

# %%
# this code is to check the first 5 data in the dataset
boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio  lstat  medv
# 0  296     15.3   4.98  24.0
# 1  242     17.8   9.14  21.6
# 2  242     17.8   4.03  34.7
# 3  222     18.7   2.94  33.4
# 4  222     18.7   5.33  36.2

# %% [markdown]
# # 10b

# %%
#This code shows the shape of the datasets by showing the number of rows and colomns in the dataset
boston.shape
# Out:
# (506, 14)

# %%
#This code set variables for value number of rows and columns in the boston data set and also use a print function to display it
num_rows = boston.shape[0]
num_cols = boston.shape[1]
print("Number of rows of the boston dataset is:", num_rows, "\nNumber of columns of the boston dataset is:", num_cols)

#The rows in the dataset correspond to a different suburb in Boston with their respective observations
#The columns in the dataset represnet different features associated with the housing data for each suburb
# Out:
# Number of rows of the boston dataset is: 506
# Number of columns of the boston dataset is: 14

# %% [markdown]
# # 10c

# %%
# This code shows the pairwise scatter plots of the predictors of the boston data sets
predictors = ["crim","zn","indus","chas","nox","rm","age","dis","rad","tax","ptratio","lstat","medv"]
boston[predictors]
pd.plotting.scatter_matrix(boston[predictors],
                          figsize = (20,23))
# Out:
# array([[<AxesSubplot:xlabel='crim', ylabel='crim'>,
#         <AxesSubplot:xlabel='zn', ylabel='crim'>,
#         <AxesSubplot:xlabel='indus', ylabel='crim'>,
#         <AxesSubplot:xlabel='chas', ylabel='crim'>,
#         <AxesSubplot:xlabel='nox', ylabel='crim'>,
#         <AxesSubplot:xlabel='rm', ylabel='crim'>,
#         <AxesSubplot:xlabel='age', ylabel='crim'>,
#         <AxesSubplot:xlabel='dis', ylabel='crim'>,
#         <AxesSubplot:xlabel='rad', ylabel='crim'>,
#         <AxesSubplot:xlabel='tax', ylabel='crim'>,
#         <AxesSubplot:xlabel='ptratio', ylabel='crim'>,
#         <AxesSubplot:xlabel='lstat', ylabel='crim'>,
#         <AxesSubplot:xlabel='medv', ylabel='crim'>],
#        [<AxesSubplot:xlabel='crim', ylabel='zn'>,
#         <AxesSubplot:xlabel='zn', ylabel='zn'>,
#         <AxesSubplot:xlabel='indus', ylabel='zn'>,
#         <AxesSubplot:xlabel='chas', ylabel='zn'>,
#         <AxesSubplot:xlabel='nox', ylabel='zn'>,
# ...

# %% [markdown]
# From the scatter matrix above i can see some associations with the following predictors
#
# 1. Crim and age: as age increases crime rates (crim) increaases and vice versa, new buildings tends to have low crime rates
# 2. crim and dis: as dis increases crime rates (crim) decreases and vice versa
# 3. crim and medv: As medv increases crime rates (crim) decreases and vice versa, high values suburbs have less crime rates
# 4. Zn and indus: as zn increases the indus proportion decreases and vice versa
# 5. Zn and nox: as zn increases the porpotion of nox decreases and vice versa
# 6. dis and indus: as indus increases the proportion of dis decreases and vice versa
# 7. Age and lstat: as lstat increases the proportion of age also increases and vice versa, this means that more percentage of lower status people tends to stay at old houses.
# 8. lstat and medv: as the lstats increases the proportion or value of medv decreases and vice versa, this means that higer percentage of lower status tends to stay in suburbs with less median value of homes which really makes sense as they have less capital to afford the high value suburbs.
# 9. Medv and rm: as the medv increases the number or average room proportion increaases and vice versa, this means the higher the value of the median value of home in suburbs the more the rooms in the property, which makes sense as they spend more anount of money on the property and can afford additional rooms.

# %% [markdown]
# # 10d.

# %%
# This code plots a 3 by 4 subplots for a scatter plot of crime rate against other predictors

fig, axes = subplots(nrows = 3, ncols = 4,
                    figsize = (21,21))
axes[0,0].scatter(boston["age"], boston["crim"]) # This is a code for the scatter plot of age against crim
axes[0,0].set_title("Scatter plot of age and crime rate")
axes[0,0].set_xlabel("Age")
axes[0,0].set_ylabel("Crim")

axes[0,1].scatter(boston["zn"], boston["crim"]) # This is a code for the scatter plot of zn against crim
axes[0,1].set_title("Scatter plot of zn and crime rate")
axes[0,1].set_xlabel("zn")
axes[0,1].set_ylabel("Crim")

axes[0,2].scatter(boston["indus"], boston["crim"]) # This is a code for the scatter plot of indus against crim
axes[0,2].set_title("Scatter plot of indus and crime rate")
axes[0,2].set_xlabel("Indus")
axes[0,2].set_ylabel("Crim")

axes[0,3].scatter(boston["chas"], boston["crim"]) # This is a code for the scatter plot of chas against crim
axes[0,3].set_title("Scatter plot of chas and crime rate")
axes[0,3].set_xlabel("Chas")
axes[0,3].set_ylabel("Crim")

axes[1,0].scatter(boston["nox"], boston["crim"], color = "teal") # This is a code for the scatter plot of nox against crim
axes[1,0].set_title("Scatter plot of nox and crime rate")
axes[1,0].set_xlabel("Nox")
axes[1,0].set_ylabel("Crim")

axes[1,1].scatter(boston["rm"], boston["crim"], color = "teal") # This is a code for the scatter plot of rm against crim
axes[1,1].set_title("Scatter plot of rm and crime rate")
axes[1,1].set_xlabel("Rm")
axes[1,1].set_ylabel("Crim")

axes[1,2].scatter(boston["dis"], boston["crim"], color = "teal") # This is a code for the scatter plot of dis against crim
axes[1,2].set_title("Scatter plot of dis and crime rate")
axes[1,2].set_xlabel("Dis")
axes[1,2].set_ylabel("Crim")

axes[1,3].scatter(boston["rad"], boston["crim"], color = "teal") # This is a code for the scatter plot of rad against crim
axes[1,3].set_title("Scatter plot of rad and crime rate")
axes[1,3].set_xlabel("Rad")
axes[1,3].set_ylabel("Crim")

axes[2,0].scatter(boston["tax"], boston["crim"], color = "grey") # This is a code for the scatter plot of age against crim
axes[2,0].set_title("Scatter plot of tax and crime rate")
axes[2,0].set_xlabel("Tax")
axes[2,0].set_ylabel("Crim")

axes[2,1].scatter(boston["ptratio"], boston["crim"], color = "grey") # This is a code for the scatter plot of ptratio against crim
axes[2,1].set_title("Scatter plot of ptratio and crime rate")
axes[2,1].set_xlabel("Pupil-Teacher ratio")
axes[2,1].set_ylabel("Crim")

axes[2,2].scatter(boston["lstat"], boston["crim"], color = "grey") # This is a code for the scatter plot of lstat against crim
axes[2,2].set_title("Scatter plot of lstat and crime rate")
axes[2,2].set_xlabel("Lstat")
axes[2,2].set_ylabel("Crim")

axes[2,3].scatter(boston["medv"], boston["crim"], color = "grey") # This is a code for the scatter plot of medv against crim
axes[2,3].set_title("Scatter plot of medv and crime rate")
axes[2,3].set_xlabel("Medv")
axes[2,3].set_ylabel("Crim")
# Out:
# Text(0, 0.5, 'Crim')

# %% [markdown]
# From the scatter plots of crim against other predictors above it appears that the following predictors have some association with Crime rate (crim).
#
# Age: as the proportion of age increases the crime rate (crim) also increases
#
# Zn: as zn increase the crime rate (crim) decreases.
#
# chas: it seems that suburbs without the charles river tends to have high crime rate (crim) while the ones with charles river has low crime rate (crim)
#
# Dis: as the dis increases the crime rate (crim) decreases
#
# Rad: ad the rad of the suburbs increases the crime rate increases
#
# medv: as the median value of owner occupied homes increases the crime rate decreases. This really means that neighbourhood with high value i.e median value will have low crime rates which is ideal.

# %%
# the code beelow is the correlation of crime rate (crim) against other predictors.
n = boston.corr()
n['crim']
# Out:
# Unnamed: 0    0.407407
# crim          1.000000
# zn           -0.200469
# indus         0.406583
# chas         -0.055892
# nox           0.420972
# rm           -0.219247
# age           0.352734
# dis          -0.379670
# rad           0.625505
# tax           0.582764
# ptratio       0.289946
# lstat         0.455621
# medv         -0.388305
# Name: crim, dtype: float64

# %% [markdown]
# here you can see that crim has negative corralations with zn,chas,dis, and medv as reported in the last markdown note above. which means that as crime rate (crim) increases the 4 predictors [zn,chas,dis, and medv] decreases and vice versa. The positive correlation means that as the crime rate (crim) increases then the proportion of the predictors with positive predictors also increases.

# %% [markdown]
# # 10e.

# %%
# 
fig, axes = plt.subplots(ncols = 3, figsize = (15,5))
boston.crim.hist(ax = axes[0])
axes[0].set_xlabel("Crime Rate")
axes[0].set_ylabel("Frequency")
axes[0].set_title("Histogram of Crime rate (crim)")

boston.tax.hist(ax=axes[1])
axes[1].set_xlabel("Property Tax")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram of Tax")

boston.ptratio.hist(ax = axes[2])
axes[2].set_xlabel("Pupil-teacher ratio")
axes[2].set_ylabel("Frequency")
axes[2].set_title("Histogram of Pupil-Teacher ratio")
# Out:
# Text(0.5, 1.0, 'Histogram of Pupil-Teacher ratio')

# %%
# This code below is for the percentage of crime rate more than 10%
crim10 = boston[boston["crim"] > 10]
row_crim10 = crim10.shape[0]
perc_crim10 = row_crim10/num_rows * 100

#This code below is for the percentage of crime rate more than 20%
crim20 = boston[boston["crim"] > 20]
row_crim20 = crim20.shape[0]
perc_crim20 = row_crim20/num_rows * 100

print ("We have", perc_crim10, "% of the suburbs with crime rate more than 10% \nwhile we have", perc_crim20,"% of the suburbs with crime rate more than 20%")
# Out:
# We have 10.67193675889328 % of the suburbs with crime rate more than 10%
# while we have 3.557312252964427 % of the suburbs with crime rate more than 20%

# %%
boston3 = boston[["crim","tax","ptratio"]]
boston3.describe()
# Out:
#              crim         tax     ptratio
# count  506.000000  506.000000  506.000000
# mean     3.613524  408.237154   18.455534
# std      8.601545  168.537116    2.164946
# min      0.006320  187.000000   12.600000
# 25%      0.082045  279.000000   17.400000
# 50%      0.256510  330.000000   19.050000
# 75%      3.677083  666.000000   20.200000
# max     88.976200  711.000000   22.000000

# %% [markdown]
# >>> From the histogram there are only few suburbs that have high crime rates. With the calcuation we can see that only 10.67% of the suburbs have crime rates more than 10% and 3.56% of the suburbs have crime rate more than 20%.
#
# >>> From the decription of boston data set the average tax is $408.24 and the median(50% quartile) of the tax data is $330 which means that a lot of suburbs pay lower rates compared to high rates. Also on the histogram we can see a spike in amount of people paying high rates of up to 135 in frequency paying between (600-700) as tax.
#
# >>> From the description we have the mean as 18.46 and the median(50% quartiles) as 19.05 which denotes that more than half of the suburbs have more than the average pupil teacher ratio. And from the histogram we can see a spike of 175 frequency between 20-21. from the observation we have more suburbs with high pupil teacher ratio though the difference is just a slight difference.

# %%
# This code below is to calculate the range of the values in crim, tax and ptratio column respectively
range_crim = boston.crim.max() - boston.crim.min()
range_tax = boston.tax.max() - boston.tax.min()
range_ptratio = boston.ptratio.max() - boston.ptratio.min()
print ("The range of Crime rate is : ", range_crim, "\nThe range of tax is :", range_tax, 
       "\nThe range of pupil-teacher ratio is :", range_ptratio)
# Out:
# The range of Crime rate is :  88.96988
# The range of tax is : 524
# The range of pupil-teacher ratio is : 9.4

# %% [markdown]
# The range of crime rate  (crim) is 88.97, the range of tax is 524 which is much and the range if pupil teacher ratio is 9.4

# %% [markdown]
# # 10f.

# %%
# the code below show the number of boston suburbs with charles river
charles_r = boston['chas'] == 1
charlesr_rows = boston[charles_r].shape[0]
print ("The suburbs that have Charles river is:",charlesr_rows)
# Out:
# The suburbs that have Charles river is: 35

# %% [markdown]
# # 10g.

# %%
#this code below is to calculate the median value of pupil-teacher ratio of the boston data set
med_ptratio = boston["ptratio"].median()
print ("The median value of the pupil-teacher ratio is:",med_ptratio)
# Out:
# The median value of the pupil-teacher ratio is: 19.05

# %% [markdown]
# # 10h.

# %%
# this code below is to show the suburbs with the lowest median value in the boston data set
low_medv = boston["medv"] == boston["medv"].min()
print ("The lowest median value (medv) in the boston data set is:", boston["medv"].min(),"\nand the suburbs and the other predictors are below")
boston[low_medv]
# Out:
# The lowest median value (medv) in the boston data set is: 5.0
# and the suburbs and the other predictors are below
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 398         399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24
# 405         406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24
#
#      tax  ptratio  lstat  medv
# 398  666     20.2  30.59   5.0
# 405  666     20.2  22.98   5.0

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# we have suburbs 399 and 406 as the only suburbs with lowest median values(medv)
#
# Crim: suburb 399 has (38.35) crime rate and this is more than 10 times the average of boston suburbs (3.61), Also suburb 406 has a crime rate (67.92) of up to 20 times of the average crime rate of the boston suburb. Which means that the lowest medv have high crime rate in their suburbs.
#
# Zn: suburb 399 and 406 have (0) zn and this is below the average of the boston suburbs (11.36).
#
# Indus: Both suburb 399 and 406 have (18.1) indus and this is above the average of the boston suburbs.
#
# chas: Both suburb 399 and 406 have (0) chas and this is above the avergae of the boston suburbs(0.069). This means that the both suburbs dont have charles river.
#
# nox: Both suburbs 399 and 406 have (0.693) nox which is slightly above the average of the boston suburbs of (0.55).
#
# Rm: suburb 399 has (5.45) rm which is below the average of the boston suburb of (6.28).
#
# Age: Both suburb 399 and 406 have age of (100) which is above the average in the boston suburb (68.57) and which is also the maximum of the boston suburb (100). This meams that the suburbs have the highest value of age in the boston dataset
#
# Dis: suburb 399 has (1.49)dis which is below the average of the boston suburbs (3.79) and also suburb 406 have a dis (1.43) below the average boston suburb
#
# Rad: Both suburb 399 and 406 have (24) which is above the avergae boston suburbs (9.55).
#
# Tax: Both suburb 399 and 406 have (666) tax which is above the average tax rate of boston suburbs (408.24), which means that they both pay high tax rate.
#
# Ptratio: Both suburb 399 and 406 have (20.2) ptratio which is above the average of boston suburbs (18.45)
#
# Lstat: Suburb 399 has (30.59) lstat which is above the average of the boston suburbs, also suburb 406 has (22.98) lstat which is also above the average of boston suburbs.
#
# Medv: Both suburbs have the same medv (5) which is below the avergae of boston suburbs (22.53) and which is also the lowest value in the medv.

# %% [markdown]
# # 10i.

# %%
# this code below shows the number of suburbs with more than 7 and 8 rooms respectively.
room7 = boston["rm"]> 7
room8 = boston["rm"] > 8
print ("The number of suburbs that have more than 7 rooms is:", boston[room7].shape[0], "\nThe number of suburbs that have more than 8 rooms is:", boston[room8].shape[0])
# Out:
# The number of suburbs that have more than 7 rooms is: 64
# The number of suburbs that have more than 8 rooms is: 13

# %%
# this code below show the stats of the predictors of suburbs with rooms(rm) more than 8
boston[room8].describe()
# Out:
#        Unnamed: 0       crim         zn      indus       chas        nox  \
# count   13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean   232.307692   0.718795  13.615385   7.078462   0.153846   0.539238
# std     60.915768   0.901640  26.298094   5.392767   0.375534   0.092352
# min     98.000000   0.020090   0.000000   2.680000   0.000000   0.416100
# 25%    225.000000   0.331470   0.000000   3.970000   0.000000   0.504000
# 50%    233.000000   0.520140   0.000000   6.200000   0.000000   0.507000
# 75%    258.000000   0.578340  20.000000   6.200000   0.000000   0.605000
# max    365.000000   3.474280  95.000000  19.580000   1.000000   0.718000
#
#               rm        age        dis        rad         tax    ptratio  \
# count  13.000000  13.000000  13.000000  13.000000   13.000000  13.000000
# mean    8.348538  71.538462   3.430192   7.461538  325.076923  16.361538
# std     0.251261  24.608723   1.883955   5.332532  110.971063   2.410580
# ...

# %% [markdown]
# The following are the noticeable details for rooms with more than 8 in the boston datasets
#
# 1. They have low crime rate with an average of (0.72) and with highest crime rate of 3.47
# 2. They have an avergae of lstat of (4.31) which is below the boston average (12.65)
# 3. They have an average of (13.62) in zn and uptil the median the value is (0). the 75% quartile is 20 and maximum value of 95
# 4. most of the suburbs dont have charles river uptil 75% quartile the value is (0)
